# %%
# %pylab inline 
import pickle as pkl 
from tqdm import tqdm
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
def multi_ploter(t, s, i):
# dark blue, orange, red, brown, green, black
    y = 5*i
    
    plt.plot(t, s[:,y+0], label=f'S$_{i}$', color='#000080')
    plt.plot(t, s[:,y+1], label=f'E$_{i}$', color='#FFA500')
    plt.plot(t, s[:,y+2], label=f'I$_{i}$', color='#FF0000')
    plt.plot(t, s[:,y+3], label=f'H$_{i}$', color='#8B4513')
    plt.plot(t, s[:,y+4], label=f'R$_{i}$', color='#008000')
    plt.plot(t, s[:,y+5], label=f'K$_{i}$', color='#000000')
    
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Fraction of population')
    # display only 3 ticks on the x-axis
    # plt.xticks(np.linspace(0, t[-1], 3))
    # display only 5 ticks on the y-axis
    # plt.yticks(np.linspace(0, 1, 5))
    plt.show()
    return

# %%
for i in range(1,51):
    s = pkl.load(open("./Data/s_ER_Imax_0.5_SD.pkl","rb"))
    multi_ploter(linspace(0,1000,50),s,i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb Cell 3 in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for i in range(1,51):
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     s = pkl.load(open("./Data/s_ER_Imax_0.5_SD.pkl","rb"))
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     multi_ploter(linspace(0,1000,50),s,i)
#
# /home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb Cell 3 in multi_ploter(t, s, i)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> y = 5*i
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.plot(t, s[:,y+0], label=f'S$_{i}$', color='#000080')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> plt.plot(t, s[:,y+1], label=f'E$_{i}$', color='#FFA500')
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> plt.plot(t, s[:,y+2], label=f'I$_{i}$', color='#FF0000')
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode030/home2/ashu_bharadwaj/DPCN/DPCN_Project/visualizer.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> plt.plot(t, s[:,y+3], label=f'H$_{i}$', color='#8B4513')
#
# IndexError: index 251 is out of bounds for axis 1 with size 251
